# %%
import pandas as pd

#emmissions data into dictionary 
data={'Low Altitude': [1.50, 1.48, 2.98, 1.40, 3.12, 0.25, 6.73, 5.30, 9.30, 
                       6.96, 7.21, 0.87, 1.06, 7.39, 1.37], 
            'High Altitude': [7.59, 2.06, 8.86, 8.67, 5.61, 6.28, 4.04, 4.40,
                               9.52, 1.50, 6.07, 17.11, 3.57, 2.68, 6.46]}  

#convert emissions data to dataframe
emissions = pd.DataFrame(data)

#specify name of excel file
excel_file = 'emissions_from_pandas.xlsx'

#specify excel sheet name
sheetName= 'Particulate matter (PM) emissions'

#exporting as an excel file: do i have to assign this as a variable?
emissions.to_excel(excel_file,  index=False)

print("Emissions exported to 'emissions_from_pandas.xls' successfully")
# Out:
# Emissions exported to 'emissions_from_pandas.xls' successfully
#    Low Altitude  High Altitude
# 2          2.98           8.86
# 3          1.40           8.67

# %%
emissions.head()
# Out:
#    Low Altitude  High Altitude
# 0          1.50           7.59
# 1          1.48           2.06
# 2          2.98           8.86
# 3          1.40           8.67
# 4          3.12           5.61

# %%
#returns the first value in the data set in the array position 0,0
emissions.iloc[0,0]
# Out:
# 1.5

# %%
#returns the value in the 1,1 position
emissions.iloc[1,1]
# Out:
# 2.06

# %%
emissions.iloc[0:2,0:2] #see the first two rows and the first 2 columns
# Out:
#    Low Altitude  High Altitude
# 0          1.50           7.59
# 1          1.48           2.06

# %%
#returns the set of values for rows 2 and 3
emissions.iloc[2:4,:]
# Out:
#    Low Altitude  High Altitude
# 2          2.98           8.86
# 3          1.40           8.67

# %%
import pandas as pd
#File conversion

#creating variable                  
#
emissions_from_excel = pd.read_excel('emissions_from_pandas.xlsx' )

#show first five rows of table
emissions_from_excel.head()
# Out:
#    Low Altitude  High Altitude  Unnamed: 2 Unnamed: 3  Low Altitude.1  \
# 0          1.50           7.59         NaN      count       15.000000
# 1          1.48           2.06         NaN       mean        3.794667
# 2          2.98           8.86         NaN        std        3.020801
# 3          1.40           8.67         NaN        min        0.250000
# 4          3.12           5.61         NaN       0.25        1.385000
#
#    High Altitude.1
# 0        15.000000
# 1         6.294667
# 2         3.890521
# 3         1.500000
# 4         3.805000

# %% [markdown]
# # TASK 2. NUMERICAL AND GRAPHICAL SUMMARY OF DATASETS USING
#
# # PYTHON AND PANDAS
# Report the following statistics for the emissions data (in Task 1) both at low and high altitude:
# sample size or count, sample mean, sample standard deviation (std), minimum, maximum,
# median, first and third quartile.
# (Note: As mentioned in the textbook, different software packages calculate quartiles in slightly
# different ways, so do not worry if your quartile values is slightly different from someone else
# who use a different method.)

# %% [markdown]
# ## Method 1: Use Arithmetic Operations

# %%
import numpy as np
''' (a)-Use python (any library, but pandas will be fast). You can past screenshot of both input and
output '''
#create array of data items
low_altitude = np.array([emissions_from_excel['Low Altitude']])
print (low_altitude)
high_altitude = np.array([emissions_from_excel['High Altitude']])

##calculating sample size: 
high_count = len(high_altitude)
low_count = len(low_altitude)

#calulating mean
##use mean function
low_mean = round(np.mean(low_altitude))
high_mean = round(np.mean(high_altitude))

#calulating std (standard deviation)
low_std = round(np.std(low_altitude, ddof=1))
high_std = round(np.std(high_altitude,ddof=1))

#calulating min
low_min = np.min(low_altitude)
high_min = np.min(high_altitude)
#calulating first quartile (25%)
low_quart1 = np.percentile(low_altitude, 25)
high_quart1 = np.percentile(high_altitude, 25)

#calulating median (50%)
low_median = np.percentile(low_altitude, 50)
high_median = np.percentile(high_altitude, 50)

#calulating third quartile (75%)
low_quart3 = np.percentile(low_altitude, 75)
high_quart3 = np.percentile(high_altitude, 75)

#calculating max
low_max = np.max(low_altitude)
high_max = np.max(high_altitude)


#adding the values to the data set.
summary={"Summary": ["count", 'mean', 'std', 'min', '25%', '50%', '75%', 'max'],
      'Low Altitude': [low_count, low_mean, low_std, low_min, low_quart1, low_median, low_quart3, low_max], 
     'High Altitude': [high_count, high_mean, high_std, high_min, high_quart1, high_median, high_quart3, high_max]}  

summary_data = pd.DataFrame(summary)
#OR

summary = pd.DataFrame()
summary['Summary']= ["count", 'mean', 'std', 'min', '25%', '50%', '75%', 'max']
summary['Low Altitude']= [low_count, low_mean, low_std, low_min, low_quart1, low_median, low_quart3, low_max]
summary['High Altitude'] = [high_count, high_mean, high_std, high_min, high_quart1, high_median, high_quart3, high_max]
emissions_from_excel.describe()
# Out:
# [[1.5  1.48 2.98 1.4  3.12 0.25 6.73 5.3  9.3  6.96 7.21 0.87 1.06 7.39
#   1.37]]
#        Low Altitude  High Altitude
# count     15.000000      15.000000
# mean       3.794667       6.294667
# std        3.020801       3.890521
# min        0.250000       1.500000
# 25%        1.385000       3.805000
# 50%        2.980000       6.070000
# 75%        6.845000       8.130000
# max        9.300000      17.110000

# %%
#show descriptive dataframe data
emissions_from_excel.describe()
# Out:
#        Low Altitude  High Altitude  Unnamed: 2  Low Altitude.1  \
# count     15.000000      15.000000         0.0        8.000000
# mean       3.794667       6.294667         NaN        5.321934
# std        3.020801       3.890521         NaN        4.871874
# min        0.250000       1.500000         NaN        0.250000
# 25%        1.385000       3.805000         NaN        2.581250
# 50%        2.980000       6.070000         NaN        3.407734
# 75%        6.845000       8.130000         NaN        7.458750
# max        9.300000      17.110000         NaN       15.000000
#
#        High Altitude.1
# count         8.000000
# mean          7.725023
# std           5.539121
# min           1.500000
# 25%           3.869141
# 50%           6.182333
# 75%           9.847500
# max          17.110000

# %%
#create boxplot
import pandas as pd
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.boxplot(emissions_from_excel)

plt.xlabel("Altitudes (1 = Low, 2 = High)")
plt.ylabel("Altitude Values")
plt.show()

# %%
# Task 3: Importance of Graphs
#a
import pandas as pd
import matplotlib.pyplot as py
dataset1= pd.DataFrame()

dataset1['x'] = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 
                 4.0, 12.0, 7.0, 5.0]
dataset1['y'] = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 
                 7.24, 4.26, 10.84, 4.82, 5.68]

#describe data set
dataset1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
#b
import pandas as pd
dataset2 = pd.DataFrame()

dataset2['x'] = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 
                 6.0, 4.0, 12.0, 7.0, 5.0]
dataset2['y'] = [9.14, 8.14, 8.78, 8.77, 9.26, 8.10, 
                 6.13, 3.10, 9.13, 7.26, 4.74]

dataset2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.504545
# std     3.316625   2.034131
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.955000
# max    14.000000   9.260000

# %% [markdown]
# # c
# yes, there are some differences in the summary statistics:
# 1.

# %%
#d 
fig, ax1 = plt.subplots(figsize=(10,10))

ax1.scatter(dataset1['x'],dataset1['y'], s=100,color="red", marker = 'o' , 
            label= "Dataset 1")
ax1.set_xlabel("x values")
ax1.set_ylabel('Dataset 1 y values')
ax1.set_title("Data sets")
ax1.legend(loc ="upper left")

ax2 = ax1.twinx()
ax2.scatter(dataset2['x'], dataset2['y'], s=100,color = 'blue', marker = '+', 
            label = "Dataset 2")
ax2.set_xlabel("x values")
ax2.set_ylabel('Dataset 2 y values')

ax2.legend(loc= "upper right")

#comment any differences between these two plots

# %%
#importing dataset
from sklearn.datasets import load_digits
digit= load_digits()
#a
digit
#print("Number of Attributes: "+ digit_dataset.data.shape)
print(digit.DESCR)
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 1797
#     :Number of Attributes: 64
#     :Attribute Information: 8x8 image of integer pixels in the range 0..16.
#     :Missing Attribute Values: None
#     :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
#     :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# ...

# %%
#importing dataset
from sklearn.datasets import load_breast_cancer
breast_cancer = load_breast_cancer()
#a
breast_cancer
#print("Number of Attributes: "+ digit_dataset.data.shape)
print(breast_cancer.keys())
print(breast_cancer.DESCR)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
# ...
